# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span><ul class="toc-item"><li><span><a href="#Подключение-библиотеки" data-toc-modified-id="Подключение-библиотеки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Подключение библиотеки</a></span></li><li><span><a href="#Загрузим-данные" data-toc-modified-id="Загрузим-данные-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузим данные</a></span></li><li><span><a href="#Изучим-данные" data-toc-modified-id="Изучим-данные-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Изучим данные</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span><ul class="toc-item"><li><span><a href="#Первый-график-временного-ряда" data-toc-modified-id="Первый-график-временного-ряда-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Первый график временного ряда</a></span></li><li><span><a href="#График-со-скользящими-средними" data-toc-modified-id="График-со-скользящими-средними-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>График со скользящими средними</a></span></li><li><span><a href="#Исследуем-стационарные-ряды" data-toc-modified-id="Исследуем-стационарные-ряды-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследуем стационарные ряды</a></span></li><li><span><a href="#Тренды-и-сезонность" data-toc-modified-id="Тренды-и-сезонность-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Тренды и сезонность</a></span></li><li><span><a href="#Проверка-на-дисперсию-математическим-способом" data-toc-modified-id="Проверка-на-дисперсию-математическим-способом-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Проверка на дисперсию математическим способом</a></span></li><li><span><a href="#Проверка-на-станционарность-математическим-способом" data-toc-modified-id="Проверка-на-станционарность-математическим-способом-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Проверка на станционарность математическим способом</a></span><ul class="toc-item"><li><span><a href="#Тест-Дики-Фуллера" data-toc-modified-id="Тест-Дики-Фуллера-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>Тест Дики-Фуллера</a></span></li><li><span><a href="#Тест-KPSS---Квятковский-Филлипс-Шмидт-ШинаДики-Фуллер" data-toc-modified-id="Тест-KPSS---Квятковский-Филлипс-Шмидт-ШинаДики-Фуллер-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>Тест KPSS - Квятковский-Филлипс-Шмидт-ШинаДики-Фуллер</a></span></li></ul></li></ul></li><li><span><a href="#Обучение-и-тестирование" data-toc-modified-id="Обучение-и-тестирование-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение и тестирование</a></span><ul class="toc-item"><li><span><a href="#Деление-на-обучающей-и-тестовой-выборки" data-toc-modified-id="Деление-на-обучающей-и-тестовой-выборки-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Деление на обучающей и тестовой выборки</a></span></li><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#DecisionTreeRegressor" data-toc-modified-id="DecisionTreeRegressor-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>DecisionTreeRegressor</a></span></li><li><span><a href="#RandomForestRegressor" data-toc-modified-id="RandomForestRegressor-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>RandomForestRegressor</a></span></li><li><span><a href="#LightGBMRegressor" data-toc-modified-id="LightGBMRegressor-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>LightGBMRegressor</a></span></li><li><span><a href="#CatBoostRegressor" data-toc-modified-id="CatBoostRegressor-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>CatBoostRegressor</a></span></li><li><span><a href="#Результаты" data-toc-modified-id="Результаты-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Результаты</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# ## Подготовка

# %% [markdown]
# ### Подключение библиотеки

# %%
# !pip install -q jupyternotify

# %%
# Уведомление о завершение работы определенного ячейка (очень пригодится для машинного обучения)
import jupyternotify
# %load_ext jupyternotify
# Out:
# The jupyternotify extension is already loaded. To reload it, use:
#   %reload_ext jupyternotify

# %%
# Подключаем все необходимые библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from scipy import stats as st
# Время обучения модели
import timeit
# Тренды и сезонность
from statsmodels.tsa.seasonal import seasonal_decompose
# Проверка на стационарность
from statsmodels.tsa.stattools import adfuller, kpss
# Проверка на дисперсию с помощью теста Андерсона-Дарлинга
from scipy.stats import anderson

from lightgbm import LGBMRegressor
# Вызов библиотеки для отключения предупреждения
import warnings

# Разбиение на обучающую, валидационную и тестовую выборку
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, cross_val_predict
# Применим кроссвалидацию для повышения качеств обучения
# Для константной модели
from sklearn.dummy import DummyRegressor
from catboost import CatBoostRegressor

# Масштабируемость модели
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder

# и для машинного обучения разными способами (по условию мы выбираем линейную регрессию):
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor

from sklearn.metrics import (
    # Точность модели
    accuracy_score,
    # Матрицы ошибок (для борьбы с дисбалансом)
    confusion_matrix, 
    # Полнота
    recall_score, 
    # Точность
    precision_score, 
    # F1-мера
    f1_score,
    # Метрика AUC-ROC
    roc_auc_score,
    roc_curve,
    # MSE
    mean_squared_error,
    mean_absolute_error,
    fbeta_score, 
    make_scorer
)

# Контроль выборки
from sklearn.utils import shuffle

# %% [markdown]
# ### Загрузим данные

# %%
df = pd.read_csv('D:/Python/yandex_practicum/taxi.csv')

# %%
# Получаем датасет
try:
    # С локального файла
    try:
        # Сразу устанавливаем время как индексы
        df = pd.read_csv('taxi.csv', index_col=[0], parse_dates=[0])
    except:
        df = pd.read_csv('/datasets/taxi.csv', index_col=[0], parse_dates=[0])
except:
    print('Отсутствует датасет. Проверьте путь файла')
# Out:
# Отсутствует датасет. Проверьте путь файла

# %% [markdown]
# ### Изучим данные

# %%
display(df.info())

display(df.describe())

display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26496 entries, 0 to 26495
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    26496 non-null  object
#  1   num_orders  26496 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 414.1+ KB
# None
#          num_orders
# count  26496.000000
# mean      14.070463
# std        9.211330
# min        0.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max      119.000000
#               datetime  num_orders
# 0  2018-03-01 00:00:00           9
# 1  2018-03-01 00:10:00          14
# 2  2018-03-01 00:20:00          28
# 3  2018-03-01 00:30:00          20
# 4  2018-03-01 00:40:00          32

# %% [markdown]
# Видно, что средний заказ составляет `14`. А самым **максимальным** заказом был `119`. А сколько - за час, за день, за месяц, об этом нельзя сказать, пока не ресемплируем данные и сделаем анализ

# %% [markdown]
# ### Предобработка данных

# %%
# Отсортируем данные на всякий
df.sort_index(inplace=True)

# %%
# Ресемплирируем данные по часами
df = df.resample('1H').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Ресемплирируем данные по часами
# ----> 2 df = df.resample('1H').sum()
#
# File D:\Program File\Anaconda\envs\practicum\lib\site-packages\pandas\core\frame.py:11392, in DataFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#   11375 @doc(NDFrame.resample, **_shared_doc_kwargs)
#   11376 def resample(
#   11377     self,
#    (...)
#   11390     group_keys: bool | lib.NoDefault = no_default,
#   11391 ) -> Resampler:
# > 11392     return super().resample(
#   11393         rule=rule,
#   11394         axis=axis,
#   11395         closed=closed,
#   11396         label=label,
#   11397         convention=convention,
#   11398         kind=kind,
#   11399         loffset=loffset,
#   11400         base=base,
#   11401         on=on,
#   11402         level=level,
#   11403         origin=origin,
#   11404         offset=offset,
#   11405         group_keys=group_keys,
#   11406     )
#
# File D:\Program File\Anaconda\envs\practicum\lib\site-packages\pandas\core\generic.py:8858, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#    8855 from pandas.core.resample import get_resampler
#    8857 axis = self._get_axis_number(axis)
# -> 8858 return get_resampler(
#    8859     self,
#    8860     freq=rule,
#    8861     label=label,
#    8862     closed=closed,
#    8863     axis=axis,
#    8864     kind=kind,
#    8865     loffset=loffset,
#    8866     convention=convention,
#    8867     base=base,
#    8868     key=on,
#    8869     level=level,
#    8870     origin=origin,
#    8871     offset=offset,
#    8872     group_keys=group_keys,
#    8873 )
#
# File D:\Program File\Anaconda\envs\practicum\lib\site-packages\pandas\core\resample.py:1544, in get_resampler(obj, kind, **kwds)
#    1540 """
#    1541 Create a TimeGrouper and return our resampler.
#    1542 """
#    1543 tg = TimeGrouper(**kwds)
# -> 1544 return tg._get_resampler(obj, kind=kind)
#
# File D:\Program File\Anaconda\envs\practicum\lib\site-packages\pandas\core\resample.py:1725, in TimeGrouper._get_resampler(self, obj, kind)
#    1720 elif isinstance(ax, TimedeltaIndex):
#    1721     return TimedeltaIndexResampler(
#    1722         obj, groupby=self, axis=self.axis, group_keys=self.group_keys
#    1723     )
# -> 1725 raise TypeError(
#    1726     "Only valid with DatetimeIndex, "
#    1727     "TimedeltaIndex or PeriodIndex, "
#    1728     f"but got an instance of '{type(ax).__name__}'"
#    1729 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %% [markdown]
# ## Анализ

# %% [markdown]
# ### Первый график временного ряда

# %%
# Рассмотрим график и узнаем о нем
df.plot(figsize = (25,10))

# %% [markdown]
# Вполне нормальный график, виден медленный рост заказа. Однако есть сильный разброс, это вполне нормально, т.к. бывают праздничные дни, какие то мероприятия, пятничные дни и т.д.

# %% [markdown]
# ### График со скользящими средними

# %%
# Добавим скользящие среднее
df['rolling_mean'] = df.rolling(10).mean()

# %%
# И снова рассмотрим график и узнаем о нем
df.plot(figsize=(20,10))

# %% [markdown]
# Здесь получилось неудобной и неинформативной, рассмотрим определенный промежуток времени, например, пусть промежуток времени с марта по апреля

# %%
# И снова рассмотрим график и узнаем о нем
df['2018-03':'2018-04'].plot(figsize=(20,10))

# %% [markdown]
# ### Исследуем стационарные ряды

# %%
df['std'] = df['num_orders'].rolling(15).std()

# %%
# И снова рассмотрим график и узнаем о нем
df['2018-03':'2018-04'].plot(figsize=(20,10))

# %%
# Рассмотрим еще детально, пусть, за месяц
df['2018-03-01':'2018-04-01'].plot(figsize=(20,10))

# %% [markdown]
# *Примечание*:
# - **Стохастический процесс** - это случайная величина, у которой со временем меняется её распределение. У этой величины есть среднее и дисперсия, которые тоже меняются
#
# Стохастический процесс стационарный (англ. stationary stochastic process), если его распределение со временем не меняется. Например, к такому процессу относятся периодические колебания значений
#
# Если распределение меняется, то процесс называется нестационарным

# %% [markdown]
# А что насчет временный ряд, его можно назвать стационарным или нет - нельзя, пока не проверим на тренды, сезонность и остаток декомпозиции

# %% [markdown]
# ### Тренды и сезонность

# %%
decomposed = seasonal_decompose(df['num_orders'])

# %%
# Тренд
decomposed.trend.plot(ax=plt.gca(), figsize=(20,10))

plt.title('Тренд')

# %% [markdown]
# Видно, что тренд в последнее время увеличивается, т.е. с июня больше заказов на такси поступают нежели остальных

# %%
# Сезонность
decomposed.seasonal.plot(ax=plt.gca(), figsize=(20,10))
plt.title('Сезонность')

# %% [markdown]
# Это говорит о том, что заказ стабилен и в любом сезоне, т.е. заказы всегда и будут поступать в любом времени сезона

# %%
# Сезонность
decomposed.resid.plot(ax=plt.gca(), figsize=(20,10))
plt.title('Остаток декомпозиции')

# %% [markdown]
# ### Проверка на дисперсию математическим способом

# %% [markdown]
# Можно проверить дисперсию, применяя теста Андерсона-Дарлинга

# %%
# x - временной ряд
# dist='norm' - ожидаемое распределение (нормальное)
result = anderson(x=df['num_orders'], dist='norm')

# Статистика теста
test_statistic = result.statistic

# Критические значения для разных уровней значимости (1%, 5%, 10%)
critical_values = result.critical_values

# Если статистика теста больше критического значения для выбранного уровня значимости, то дисперсия не является постоянной
if test_statistic > critical_values[2]:
    print("Дисперсия не является постоянной")
else:
    print("Дисперсия является постоянной")

# %% [markdown]
# Здесь можно сказать, что этот промежуток времени, т.е. с марта 2018 до конца, является нестанционарным, т.к. присутствует тренд, который стремится увеличиваться, это можно заметить с момента июля 2018. А также дисперсия не является постоянной. Проверим на станционарность математическим способом, что она скажет

# %% [markdown]
# ### Проверка на станционарность математическим способом

# %% [markdown]
# #### Тест Дики-Фуллера

# %%
print('='*100)
# тест Дики-Фуллера на стационарность
print('Тест Дики-Фуллера на стационарность')
print('='*100)
result = adfuller(df['num_orders'])

print('ADF Статистка: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
    
print('='*100)

if(result[1] < 0.05):
    print('Принимаем альтернативную гипотезу. Временной ряд стационарен')
else:
    print('Отвергаем альтернативную гипотезу. Временной ряд не стационарен')
print('='*100)

# %% [markdown]
# #### Тест KPSS - Квятковский-Филлипс-Шмидт-ШинаДики-Фуллер

# %%
print('='*100)
# KPSS-тест на стационарность
# KPSS - Квятковского-Филлипса-Шмидта-Шина
print('KPSS-тест на стационарность')
print('='*100)
result = kpss(df['num_orders'])
print('KPSS Статистка: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[3].items():
    print('\t%s: %.3f' % (key, value))
    
print('='*100)
#### Тест Дики-Фуллера
if(result[1] < 0.05):
    print('Принимаем альтернативную гипотезу. Временной ряд стационарен')
else:
    print('Отвергаем альтернативную гипотезу. Временной ряд не стационарен')
print('='*100)

# %% [markdown]
# 2 разные теста одно и то же говорит, а по графику не сможем судить, что является стационарен. Если приглядеться, то можно увидеть небольшой рост, хоть капельку

# %% [markdown]
# ## Обучение и тестирование

# %%
# Здесь будем сохранить результаты машинного обучения
results = pd.DataFrame()

# А это будет счетчтиком для нумерация моеделй
count_model = 0

# %%
# Создадим признаки, чтобы правильно обучить модель
def make_features(data, column, max_lag, rolling_mean_size):
    data['year'] = data.index.year
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data[column].shift(lag)

    data['rolling_mean'] = data[column].shift().rolling(rolling_mean_size).mean()

# %% [markdown]
# ### Деление на обучающей и тестовой выборки

# %%
# Создадим класс, который автоматически будет добиваться минимального RMSE
class search_small_rmse:
    # По умолчанию создается, если ничего не передаем аргументы
    def __init__(self, data):
        self.data = data
        self.rmse_v = 1_000_000
        self.max_lag = 1
        self.rolling_mean_size = 1
    
    # Создадим признаки, чтобы правильно обучить модель
    def make_features(self, data, column):
        data['year'] = data.index.year
        data['month'] = data.index.month
        data['day'] = data.index.day
        data['dayofweek'] = data.index.dayofweek

        for lag in range(1, self.max_lag + 1):
            data['lag_{}'.format(lag)] = data[column].shift(lag)

        data['rolling_mean'] = data[column].shift().rolling(self.rolling_mean_size).mean()

    # Разбиение на обучающие и тестовые выборки
    def make_train_test_split(self, name_features, name_target, test_size, random_state, shuffle=True):
        # Разделим обучающую и тестовую выборку
        self.train, self.test = train_test_split(self.data, test_size=test_size, random_state=random_state, shuffle=shuffle)
        self.train = self.train.dropna()
        
        self.features_train = self.train.drop(name_features, axis=1)
        self.target_train = self.train[name_target]

        self.features_test = self.test.drop(name_features, axis=1)
        self.target_test = self.test[name_target]
        
    # Здесь будет бесконечная итерация, которая добивается введенного желаемого RMSE
    def striving_rmse(self, name_model, parameters, cv_size, name_scoring, desired_rmse, max_value_lag, max_value_rol_mean_size):
        self.name_model = name_model
        self.parameters = parameters
        self.cv_size = cv_size
        self.name_scoring = name_scoring
        self.desired_rmse = desired_rmse
        self.max_value_lag = max_value_lag
        self.max_value_rol_mean_size = max_value_rol_mean_size


        for max_lag in range(1, max_value_lag):
            for rolling_mean_size in range(1, max_value_rol_mean_size):
                self.make_features(self.data, self.target_train)

                # Инициализируем модель
                self.model = GridSearchCV(name_model, param_grid = parameters, cv = cv_size, scoring = name_scoring)

                self.learning_model(self.features_train, self.target_train)
                self.predicting_model(self.features_test)

                if(self.rmse_v > self.desired_rmse):
                    print('Successfully')
                    break

    
    # Обучим модель на обучающей выборке
    def learning_model(self, features_train, target_train):
        self.model.fit(features_train, target_train)
        self.rmse_t = -model.best_score_
        self.refit_time_t = -model.refit_time_

    # Получим предсказания на тестовой выборки
    def predicting_model(self, features_test):
        self.features_test = features_test
        
        start_time = timeit.default_timer()
        
        self.predictions = self.model.predict(self.features_test)

        self.elapsed = round(timeit.default_timer() - start_time, 3)

        self.rmse_v = mean_squared_error(target_test, predictions, squared=False)

# %%
# На всякий случай сделаем копию, чтобы было удобно организовать несколько подборов
df_copy = df.copy()

# %%
df_class = search_small_rmse(df_copy)

# %%
df_class.make_train_test_split(name_features='num_orders', name_target='num_orders', test_size=0.1, random_state=12345, shuffle=False)

# %%
df_class.striving_rmse(name_model=LinearRegression(), parameters={}, cv_size=5, name_scoring='neg_root_mean_squared_error', desired_rmse=48, max_value_lag=24, max_value_rol_mean_size=48)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df_class.striving_rmse(name_model=LinearRegression(), parameters={}, cv_size=5, name_scoring='neg_root_mean_squared_error', desired_rmse=48, max_value_lag=24, max_value_rol_mean_size=48)
#
# Cell In[78], line 47, in search_small_rmse.striving_rmse(self, name_model, parameters, cv_size, name_scoring, desired_rmse, max_value_lag, max_value_rol_mean_size)
#      45 for max_lag in range(1, max_value_lag):
#      46     for rolling_mean_size in range(1, max_value_rol_mean_size):
# ---> 47         self.make_features(self.data, self.target_train)
#      49         # Инициализируем модель
#      50         self.model = GridSearchCV(name_model, param_grid = parameters, cv = cv_size, scoring = name_scoring)
#
# Cell In[78], line 12, in search_small_rmse.make_features(self, data, column)
#      11 def make_features(self, data, column):
# ---> 12     data['year'] = data.index.year
#      13     data['month'] = data.index.month
#      14     data['day'] = data.index.day
#
# AttributeError: 'RangeIndex' object has no attribute 'year'

# %%
# На всякий случай сделаем копию, чтобы было удобно организовать несколько подборов
df_copy = df.copy()

# %%
# Функция для создания новых признаков
make_features(df_copy,'num_orders', 48, 96)

# %%
# Разделим обучающую и тестовую выборку
train, test = train_test_split(df_copy, test_size=(1 - 0.9), random_state=12345, shuffle=False)
train = train.dropna()

# %%
features_train = train.drop(['num_orders', 'std'], axis=1)
target_train = train['num_orders']

features_test = test.drop(['num_orders', 'std'], axis=1)
target_test = test['num_orders']

# %%
# Проверим
print(features_train.shape)
print(features_test.shape)
# Out:
# (3878, 53)
# (442, 53)

# %%
print('Размер обучающей выборки:', round(features_train.shape[0] / df_copy.shape[0], 2), '%')
print('Размер тестовой выборки:', round(features_test.shape[0] / df_copy.shape[0], 2), '%')
# Out:
# Размер обучающей выборки: 0.88 %
# Размер тестовой выборки: 0.1 %

# %%
# Проверим на пропущенные значения
print('-'*100)
print('features_train')
display(features_train.isna().sum())
print('-'*100)
print('features_test')
display(features_test.isna().sum())
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# features_train
# rolling_mean    0
# year            0
# month           0
# day             0
# dayofweek       0
# lag_1           0
# lag_2           0
# lag_3           0
# lag_4           0
# lag_5           0
# lag_6           0
# lag_7           0
# lag_8           0
# lag_9           0
# lag_10          0
# lag_11          0
# lag_12          0
# lag_13          0
# lag_14          0
# lag_15          0
# lag_16          0
# lag_17          0
# lag_18          0
# lag_19          0
# lag_20          0
# lag_21          0
# lag_22          0
# lag_23          0
# lag_24          0
# lag_25          0
# lag_26          0
# lag_27          0
# lag_28          0
# lag_29          0
# lag_30          0
# lag_31          0
# lag_32          0
# lag_33          0
# lag_34          0
# lag_35          0
# lag_36          0
# lag_37          0
# lag_38          0
# lag_39          0
# lag_40          0
# lag_41          0
# lag_42          0
# lag_43          0
# lag_44          0
# lag_45          0
# lag_46          0
# lag_47          0
# lag_48          0
# dtype: int64
# ----------------------------------------------------------------------------------------------------
# features_test
# rolling_mean    0
# year            0
# month           0
# day             0
# dayofweek       0
# lag_1           0
# lag_2           0
# lag_3           0
# lag_4           0
# lag_5           0
# lag_6           0
# lag_7           0
# lag_8           0
# lag_9           0
# lag_10          0
# lag_11          0
# lag_12          0
# lag_13          0
# lag_14          0
# lag_15          0
# lag_16          0
# lag_17          0
# lag_18          0
# lag_19          0
# lag_20          0
# lag_21          0
# lag_22          0
# lag_23          0
# lag_24          0
# lag_25          0
# lag_26          0
# lag_27          0
# lag_28          0
# lag_29          0
# lag_30          0
# lag_31          0
# lag_32          0
# lag_33          0
# lag_34          0
# lag_35          0
# lag_36          0
# lag_37          0
# lag_38          0
# lag_39          0
# lag_40          0
# lag_41          0
# lag_42          0
# lag_43          0
# lag_44          0
# lag_45          0
# lag_46          0
# lag_47          0
# lag_48          0
# dtype: int64
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Нет пропущенных значений, приступаем дальше

# %% [markdown]
# ### LinearRegression

# %%
# Устанавливаем нужные параметры
parameters = {}

# Инициализируем модель
model = GridSearchCV(LinearRegression(), param_grid = parameters, cv = 5, scoring = 'neg_root_mean_squared_error')

# %%
# %%notify -m "LinearRegression"
# %%time
#
# # Обучим модель на обучающей выборке
# model.fit(features_train, target_train)
#
# # Узнаем RMSE обучающей выборки
# result_RMSE_t = -model.best_score_
# print('RMSE TRAIN:', result_RMSE_t)
# print('TIME TRAIN [s]:', round(time, 3))
# Out:
# RMSE TRAIN: 26.96991304685053
# TIME TRAIN [s]: 0.348
# CPU times: total: 46.9 ms
# Wall time: 139 ms

# %% [markdown]
# **Проверка на тестовой выборки**

# %%
# %%time
start_time = timeit.default_timer()
# Получим предсказания на тестовой выборки
predictions = model.predict(features_test)

elapsed = round(timeit.default_timer() - start_time, 3)

# Узнаем RMSE
result_RMSE_v = mean_squared_error(target_test, predictions, squared=False)
print('RMSE VALID:', result_RMSE_v)
print('Предсказание:', predictions.mean())
# Out:
# RMSE VALID: 43.75931704282299
# Предсказание: 130.85972850678732
# CPU times: total: 0 ns
# Wall time: 4 ms

# %%
# Зафиксируем результаты
results[count_model] = pd.Series({
    'NAME': 'LinearRegression', 
    'RMSE TRAIN': result_RMSE_t, 
    'RMSE VALID': result_RMSE_v, 
    'PREDICTIONS': predictions.mean(), 
    'TIME TRAINING [s]': model.refit_time_, 
    'TIME PREDICTION [s]': elapsed, 
    'PARAMETRS': model.best_params_
})

results[count_model]
count_model+=1

# %% [markdown]
# ### DecisionTreeRegressor

# %%
# Матрица гиперпараметров
parameters = {'max_depth': range(1, 201, 10), 'min_samples_leaf': [1, 0.5, 2]}

# Инициализируем модель c параметрами
model = GridSearchCV(DecisionTreeRegressor(random_state = 12345), param_grid = parameters, cv = 5, scoring = 'neg_root_mean_squared_error')

# %%
# %%notify -m "DecisionTreeRegressor"
# # %%time
#
# # Обучим модель на обучающей выборке
# model.fit(features_train, target_train)
#
# # Узнаем RMSE обучающей выборки
# result_RMSE_t = -model.best_score_
# print('RMSE TRAIN:', result_RMSE_t)
# print('TIME TRAIN [s]:', round(time, 2))
# Out:
# RMSE TRAIN: 31.497007061815196
# TIME TRAIN [s]: 0.35

# %% [markdown]
# **Проверка на тестовой выборки**

# %%
# %%time
start_time = timeit.default_timer()
# Получим предсказания на тестовой выборки
predictions = model.predict(features_test)

elapsed = round(timeit.default_timer() - start_time, 3)

result_RMSE_v = mean_squared_error(target_test, predictions, squared=False)
print('RMSE VALID:', result_RMSE_v)

print('Предсказание:', predictions.mean())
# Out:
# RMSE VALID: 56.57840477206501
# Предсказание: 134.90192555661753
# CPU times: total: 0 ns
# Wall time: 4 ms

# %%
# Зафиксируем результаты
results[count_model] = pd.Series({
    'NAME': 'DecisionTreeRegressor', 
    'RMSE TRAIN': result_RMSE_t, 
    'RMSE VALID': result_RMSE_v, 
    'PREDICTIONS': predictions.mean(), 
    'TIME TRAINING [s]': model.refit_time_, 
    'TIME PREDICTION [s]': elapsed, 
    'PARAMETRS': model.best_params_
})

results[count_model]
count_model+=1

# %% [markdown]
# ### RandomForestRegressor

# %%
# Матрица гиперпараметров для случайного леса
parameters = {'bootstrap': [True], 'max_depth': [5, 15], 'max_features': ['auto', 'log2'], 'n_estimators': [25, 50]}

# Инициализируем модель c параметрами
model = GridSearchCV(RandomForestRegressor(random_state = 12345), parameters, cv = 5, scoring = 'neg_root_mean_squared_error')

# %%
# %%notify -m "RandomForestRegressor"
# %%time
#
# # Обучим модель на обучающей выборке
# model.fit(features_train, target_train)
#
# # Узнаем RMSE обучающей выборки
# result_RMSE_t = -model.best_score_
# print('RMSE TRAIN:', result_RMSE_t)
# print('TIME TRAIN [s]:', round(time, 2))
# Out:
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# D:\Program File\Anaconda\envs\practicum\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# RMSE TRAIN: 23.55958374175849
# TIME TRAIN [s]: 0.35
# CPU times: total: 53.2 s
# Wall time: 54.6 s

# %%
# %%time
start_time = timeit.default_timer()
# Получим предсказания на тестовой выборки
predictions = model.predict(features_test)

elapsed = round(timeit.default_timer() - start_time, 3)

result_RMSE_v = mean_squared_error(target_test, predictions, squared=False)
print('RMSE VALID:', result_RMSE_v)

print('Предсказание:', predictions.mean())
# Out:
# RMSE VALID: 41.92059449252377
# Предсказание: 146.98700083515004
# CPU times: total: 0 ns
# Wall time: 8.51 ms

# %%
# Зафиксируем результаты
results[count_model] = pd.Series({
    'NAME': 'RandomForestRegressor', 
    'RMSE TRAIN': result_RMSE_t, 
    'RMSE VALID': result_RMSE_v, 
    'PREDICTIONS': predictions.mean(), 
    'TIME TRAINING [s]': model.refit_time_, 
    'TIME PREDICTION [s]': elapsed, 
    'PARAMETRS': model.best_params_
})

results[count_model]
count_model+=1

# %% [markdown]
# ### LightGBMRegressor

# %%
# Матрица гиперпараметров для LightGBMRegressor
parameters = {'num_leaves': [5, 10],
              'learning_rate': [0.1, 0.3],
              'max_depth': [3, 5],
              'n_estimators': [10, 25]}

# Инициализируем модель c параметрами
model = GridSearchCV(LGBMRegressor(), parameters, cv = 5, scoring = 'neg_root_mean_squared_error')

# %%
# %%notify -m "LightGBMRegressor"
# %%time
#
# # Обучим модель на обучающей выборке
# model.fit(features_train, target_train)
#
# # Узнаем RMSE обучающей выборки
# result_RMSE_t = -model.best_score_
# print('RMSE TRAIN:', result_RMSE_t)
# print('TIME TRAIN [s]:', round(time, 2))
# Out:
# RMSE TRAIN: 23.751787533341865
# TIME TRAIN [s]: 0.35
# CPU times: total: 23.8 s
# Wall time: 1.94 s

# %% [markdown]
# **Проверка на тестовой выборки**

# %%
# %%time
start_time = timeit.default_timer()
# Получим предсказания на тестовой выборки
predictions = model.predict(features_test)

elapsed = round(timeit.default_timer() - start_time, 3)

result_RMSE_v = mean_squared_error(target_test, predictions, squared=False)
print('RMSE VALID:', result_RMSE_v)
print('Предсказание:', predictions.mean())
# Out:
# RMSE VALID: 40.83300839480757
# Предсказание: 135.53859315034362
# CPU times: total: 0 ns
# Wall time: 3 ms

# %%
# Зафиксируем результаты
results[count_model] = pd.Series({
    'NAME': 'LightGBMRegressor', 
    'RMSE TRAIN': result_RMSE_t, 
    'RMSE VALID': result_RMSE_v, 
    'PREDICTIONS': predictions.mean(), 
    'TIME TRAINING [s]': model.refit_time_, 
    'TIME PREDICTION [s]': elapsed, 
    'PARAMETRS': model.best_params_
})

results[count_model]
count_model+=1

# %% [markdown]
# ### CatBoostRegressor

# %%
# Матрица гиперпараметров для LightGBMRegressor
parameters = {'depth' : [6, 8, 10],
              'learning_rate' : [0.01, 0.05, 0.1],
              'iterations' : [10, 15, 20]}

# Инициализируем модель c параметрами
model = GridSearchCV(CatBoostRegressor(), parameters, cv = 5, scoring = 'neg_root_mean_squared_error')

# %%
# %%notify -m "CatBoostRegressor"
# %%time
#
# # Обучим модель на обучающей выборке
# model.fit(features_train, target_train)
#
# # Узнаем RMSE обучающей выборки
# result_RMSE_t = -model.best_score_
# print('RMSE TRAIN:', result_RMSE_t)
# print('TIME TRAIN [s]:', round(time, 2))
# Out:
# 0:	learn: 38.6610350	total: 5.33ms	remaining: 48ms
# 1:	learn: 38.4833528	total: 9.61ms	remaining: 38.4ms
predictions = model.predict(features_test)

elapsed = round(timeit.default_timer() - start_time, 3)

result_RMSE_v = mean_squared_error(target_test, predictions, squared=False)
print('RMSE VALID:', result_RMSE_v)
print('Предсказание:', predictions.mean())
# Out:
# RMSE VALID: 52.466764457617806
# Предсказание: 113.02367613909273
# CPU times: total: 0 ns
# Wall time: 4 ms

# %%
# Зафиксируем результаты
results[count_model] = pd.Series({
    'NAME': 'CatBoostRegressor', 
    'RMSE TRAIN': result_RMSE_t, 
    'RMSE VALID': result_RMSE_v, 
    'PREDICTIONS': predictions.mean(), 
    'TIME TRAINING [s]': model.refit_time_, 
    'TIME PREDICTION [s]': elapsed, 
    'PARAMETRS': model.best_params_
})

results[count_model]
count_model+=1

# %% [markdown]
# ### Результаты

# %%
# %%notify -m "Total result"
# results = pd.DataFrame(results).T

# %%
# Смотрим на результаты
results
# Out:
#                     NAME RMSE TRAIN RMSE VALID PREDICTIONS TIME TRAINING [s]  \
# 0       LinearRegression  26.969913  43.759317  130.859729          0.021003
# 1  DecisionTreeRegressor  31.497007  56.578405  134.901926          0.095559
# 2  RandomForestRegressor  23.559584  41.920594  146.987001          5.414189
# 3      LightGBMRegressor  23.751788  40.833008  135.538593          0.031538
# 4      CatBoostRegressor  25.746336  52.466764  113.023676           0.26588
#
#   TIME PREDICTION [s]                                          PARAMETRS
# 0               0.002                                                 {}
# 1               0.002           {'max_depth': 11, 'min_samples_leaf': 1}
# 2               0.008  {'bootstrap': True, 'max_depth': 15, 'max_feat...
# 3               0.003  {'learning_rate': 0.3, 'max_depth': 5, 'n_esti...
# 4               0.003  {'depth': 8, 'iterations': 20, 'learning_rate'...

# %%
# Нам интересует RMSE меньше 48, тогда
best_results = results.copy()
best_results = best_results[best_results['RMSE VALID'] <  48]

# %%
best_results.sort_values(by='RMSE VALID')
# Out:
#                     NAME RMSE TRAIN RMSE VALID PREDICTIONS TIME TRAINING [s]  \
# 3      LightGBMRegressor  23.751788  40.833008  135.538593          0.031538
# 2  RandomForestRegressor  23.559584  41.920594  146.987001          5.414189
# 0       LinearRegression  26.969913  43.759317  130.859729          0.021003
#
#   TIME PREDICTION [s]                                          PARAMETRS
# 3               0.003  {'learning_rate': 0.3, 'max_depth': 5, 'n_esti...
# 2               0.008  {'bootstrap': True, 'max_depth': 15, 'max_feat...
# 0               0.002                                                 {}

# %% [markdown]
# ## Вывод

# %% [markdown]
# Самой лучшей моделей является `LightGBMRegressor` - RMSE составляет **40.83**, а скорость обучения составляет почти 0,02 секунда, время предсказания - 0,2 секунда. Вполне очень акдеватный результат, чтобы выбрать эту модель для реализации.
#
# Есть другая модель - `RandomForestRegressor`, результаты неплохие, но недостатки у нее есть - скорость обучения и предсказания.
#
# А третье место заслужила простая модель - `LinearRegression`, однако эта модель может похвастаться скоростью обучения и предсказанией

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Данные проанализированы
# - [x]  Модель обучена, гиперпараметры подобраны
# - [x]  Качество моделей проверено, выводы сделаны
# - [x]  Значение *RMSE* на тестовой выборке не больше 48
